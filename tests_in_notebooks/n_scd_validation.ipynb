# %%
import pandas as pd

# Create a sample user dataframe with first name, last name, and email
sample_users = pd.DataFrame({
    'first_name': ['John', 'Jane', 'Michael', 'Sarah', 'David'],
    'last_name': ['Smith', 'Johnson', 'Brown', 'Davis', 'Wilson'],
    'email': ['john.smith@example.com', 'jane.johnson@example.com', 'michael.brown@example.com', 'sarah.davis@example.com', 'david.wilson@example.com']
})

# Display the dataframe
print("Sample User DataFrame:")
print(sample_users)
